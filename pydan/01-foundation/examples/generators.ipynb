# %%
def counter(num: int, run_name: str):
    number = 1
    while number <= num:
        yield (number, run_name)
        number +=1

# %%
gen1 = counter(11, "run1")
gen2 = counter(2, "run2")

# %%
# while True:
#     try:
#         item = next(gen)
#         print(item)
#     except StopIteration:
#         break


for x in gen1:
    print(x)
    for y in gen2:
        print(x, y)
# Out:
# (1, 'run1')
# (1, 'run1') (1, 'run2')
# (1, 'run1') (2, 'run2')
# (2, 'run1')
# (3, 'run1')
# (4, 'run1')
# (5, 'run1')
# (6, 'run1')
# (7, 'run1')
# (8, 'run1')
# (9, 'run1')
# (10, 'run1')
# (11, 'run1')
